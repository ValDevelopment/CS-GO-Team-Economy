# %%
import numpy as np
import pandas as pd
import matplotlib as plot
import os
os.chdir(r"C:\Users\Capta\Documents\GitHub\csgo_econ_viz")

# %%
econ_data = pd.read_csv("data/raw/economy.csv", parse_dates=["date"])
results_data = pd.read_csv("data/raw/results.csv", parse_dates=["date"])
players_data = pd.read_csv("data/raw/players.csv", parse_dates=["date"])
# Out:
# C:\Users\Capta\AppData\Local\Temp\ipykernel_3608\1838040565.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   econ_data = pd.read_csv("data/raw/economy.csv", parse_dates=["date"])

# %%
players_data
# Out:
#              date player_name           team       opponent        country  \
# 0      2020-02-26      Brehze  Evil Geniuses         Liquid  United States
# 1      2020-02-26        CeRq  Evil Geniuses         Liquid       Bulgaria
# 2      2020-02-26       EliGE         Liquid  Evil Geniuses  United States
# 3      2020-02-26       Ethan  Evil Geniuses         Liquid  United States
# 4      2020-02-26         NAF         Liquid  Evil Geniuses         Canada
# ...           ...         ...            ...            ...            ...
# 383312 2015-10-07      kIMERA        ExAequo      RIP Fonty          Italy
# 383313 2015-10-07   morphiw0w        ExAequo      RIP Fonty          Italy
# 383314 2015-10-07     overfly      RIP Fonty        ExAequo          Italy
# 383315 2015-10-07     simozor      RIP Fonty        ExAequo          Italy
# 383316 2015-10-07       xullE      RIP Fonty        ExAequo          Italy
#
# ...

# %%
players_data
# Out:
#              date player_name           team       opponent        country  \
# 0      2020-02-26      Brehze  Evil Geniuses         Liquid  United States
# 1      2020-02-26        CeRq  Evil Geniuses         Liquid       Bulgaria
# 2      2020-02-26       EliGE         Liquid  Evil Geniuses  United States
# 3      2020-02-26       Ethan  Evil Geniuses         Liquid  United States
# 4      2020-02-26         NAF         Liquid  Evil Geniuses         Canada
# ...           ...         ...            ...            ...            ...
# 383312 2015-10-07      kIMERA        ExAequo      RIP Fonty          Italy
# 383313 2015-10-07   morphiw0w        ExAequo      RIP Fonty          Italy
# 383314 2015-10-07     overfly      RIP Fonty        ExAequo          Italy
# 383315 2015-10-07     simozor      RIP Fonty        ExAequo          Italy
# 383316 2015-10-07       xullE      RIP Fonty        ExAequo          Italy
#
# ...

# %%
players_data = players_data.assign(
    player_id = players_data['player_id'].astype('int16'),
    team = players_data['team'].astype('category'),
    opponent = players_data['opponent'].astype('category'),
    country = players_data['country'].astype('category'),
    event_name = players_data['event_name'].astype('category'),
    best_of = players_data['best_of'].astype('category')
)
players_data.dtypes
# Out:
# date           datetime64[ns]
# player_name            object
# team                 category
# opponent             category
# country              category
#                     ...
# m3_deaths_t           float64
# m3_kddiff_t           float64
# m3_adr_t              float64
# m3_kast_t             float64
# m3_rating_t           float64
# Length: 101, dtype: object

# %%
players_data.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383317 entries, 0 to 383316
# Columns: 101 entries, date to m3_rating_t
# dtypes: category(5), datetime64[ns](1), float64(76), int16(1), int64(14), object(4)
# memory usage: 340.4 MB

# %%
id_number = 2339402
econ_data.query("match_id == @id_number")
# Out:
#         date  match_id  event_id team_1         team_2 best_of    _map  \
# 0 2020-03-01   2339402      4901     G2  Natus Vincere       5    Nuke
# 1 2020-03-01   2339402      4901     G2  Natus Vincere       5   Dust2
# 2 2020-03-01   2339402      4901     G2  Natus Vincere       5  Mirage
#
#   t1_start t2_start    1_t1  ...  21_winner  22_winner  23_winner  24_winner  \
# 0        t       ct  4350.0  ...        NaN        NaN        NaN        NaN
# 1       ct        t  3900.0  ...        2.0        1.0        1.0        1.0
# 2        t       ct  4150.0  ...        NaN        NaN        NaN        NaN
#
#    25_winner  26_winner  27_winner  28_winner  29_winner  30_winner
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        1.0        1.0        2.0        2.0        2.0        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
#
# [3 rows x 99 columns]

# %%
results_data.query("match_id == @id_number")
# Out:
#           date team_1         team_2    _map  result_1  result_2  map_winner  \
# 658 2020-03-01     G2  Natus Vincere  Mirage         2        16           2
# 659 2020-03-01     G2  Natus Vincere    Nuke         4        16           2
# 663 2020-03-01     G2  Natus Vincere   Dust2        13        16           2
#
#      starting_ct  ct_1  t_2  t_1  ct_2  event_id  match_id  rank_1  rank_2  \
# 658            2     1    2    1    14      4901   2339402       8       6
# 659            2     3    2    1    14      4901   2339402       8       6
# 663            1     7    8    6     8      4901   2339402       8       6
#
#      map_wins_1  map_wins_2  match_winner
# 658           0           3             2
# 659           0           3             2
# 663           0           3             2

# %%
team_name = "G2"
players_data.query("team == @team_name")
# Out:
#              date player_name team     opponent   country  player_id  \
# 20     2020-02-26      AmaNEk   G2  mousesports    France       9616
# 21     2020-02-26       JaCkz   G2  mousesports    France        284
# 24     2020-02-26     huNter-   G2  mousesports    Serbia       3972
# 26     2020-02-26      kennyS   G2  mousesports    France       7167
# 27     2020-02-26        nexa   G2  mousesports    Serbia       9618
# ...           ...         ...  ...          ...       ...        ...
# 382519 2015-10-13   Maikelele   G2          TSM    Sweden       1045
# 382522 2015-10-13      dennis   G2          TSM    Sweden       1146
# 382525 2015-10-13         fox   G2          TSM  Portugal        629
# 382526 2015-10-13       jkaem   G2          TSM    Norway       8248
# 382528 2015-10-13        rain   G2          TSM    Norway       8183
#
#         match_id  event_id                  event_name  best_of  ...  \
# ...
